# %%
# Libraries for data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl

# %%
# Loading data from  table using spark
df = spark.table("retail.default.retail_sales_dataset")

# %%
rs = df.toPandas()

# %% [markdown]
# understanding the data

# %%
rs.info()

# %%
# Generating descriptive statistics such as mean, min, max, and quartiles for numerical columns
rs.describe()

# %%
# Listing all column names in the dataset
rs.columns

# %%
# Displaying the dataset
display(rs)

# %%
# Printing the entire dataset to the console
print(rs)

# %%
# Showing the first 5 rows of the dataset
rs.head()

# %%
#Showing the last 5 rows of the dataset
rs.tail()

# %%
# Counting duplicate rows in the dataset
rs.duplicated().sum()

# %%
# deleting rows with missing values
rs=rs.dropna()

# %%
# replacing the missing values with zero
rs=rs.fillna(0)

# %%
# Checking for missing (null) values in each column
rs.isnull().sum()

# %%
# Getting the shape of the dataset
rs.shape

# %%
# checking data types
rs.dtypes

# %%
display(rs)

# %%
import matplotlib.pyplot as plt

# %%
# Sales by Category (Matplotlib)
sales_by_category = rs.groupby('Product Category')['Total Amount'].sum()
plt.figure()
sales_by_category.plot(kind='bar')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure()
plt.hist(rs['Total Amount'], bins=10)
plt.title('Distribution of Sales Amount')
plt.xlabel('Sales Amount')
plt.ylabel('Frequency')
plt.show()

# %%
#

sales_by_category = rs.groupby('Product Category')['Total Amount'].sum()

plt.figure()
sales_by_category.plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales Contribution by Category')
plt.ylabel('')
plt.show()

# %%
sales_trend = rs.groupby('Date')['Total Amount'].sum()

plt.figure()
plt.plot(sales_trend, marker='o')
plt.title('Sales Trend with Markers')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Sales Trend Over Time, size changing
rs['Date'] = pd.to_datetime(rs['Date'])
sales_trend = rs.groupby('Date')['Total Amount'].sum()
plt.figure()
sales_trend.plot(color='green')
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')

plt.show()
